# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from statsmodels.graphics.gofplots import qqplot
import pandas as pd

# %%
data=pd.read_csv("C:/Users/MADHUSNATA KAR/Documents/Prodigy_Infotech/Task3_sheet.csv")
data
# Out:
#      Age  Na_to_K   Drug
# 0     23   25.355  drugY
# 1     47   13.093  drugC
# 2     47   10.114  drugC
# 3     28    7.798  drugX
# 4     61   18.043  drugY
# ..   ...      ...    ...
# 195   56   11.567  drugC
# 196   16   12.006  drugC
# 197   52    9.894  drugX
# 198   23   14.020  drugX
# 199   40   11.349  drugX
#
# [200 rows x 3 columns]

# %%
x=data.drop('Drug',axis=1)
y=data['Drug']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x)
print(y)
# Out:
#      Age  Na_to_K
# 0     23   25.355
# 1     47   13.093
# 2     47   10.114
# 3     28    7.798
# 4     61   18.043
# ..   ...      ...
# 195   56   11.567
# 196   16   12.006
# 197   52    9.894
# 198   23   14.020
# 199   40   11.349
#
# [200 rows x 2 columns]
# 0      drugY
# 1      drugC
# 2      drugC
# 3      drugX
# 4      drugY
#        ...
# 195    drugC
# 196    drugC
# 197    drugX
# 198    drugX
# 199    drugX
# Name: Drug, Length: 200, dtype: object

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(x_test)
print(y_pred)
# Out:
# ['drugX' 'drugY' 'drugX' 'drugX' 'drugY' 'drugY' 'drugY' 'drugC' 'drugX'
#  'drugX' 'drugC' 'drugA' 'drugY' 'drugA' 'drugX' 'drugY' 'drugB' 'drugC'
#  'drugX' 'drugY' 'drugB' 'drugB' 'drugB' 'drugY' 'drugY' 'drugY' 'drugX'
#  'drugC' 'drugY' 'drugC' 'drugY' 'drugA' 'drugC' 'drugY' 'drugX' 'drugY'
#  'drugC' 'drugX' 'drugY' 'drugA']

# %%
accuracy=accuracy_score(y_test,y_pred)
cm=confusion_matrix(y_test,y_pred)
cr=classification_report(y_test,y_pred) 
print(f"Accuracy:{accuracy:.2f}")
print("Confusion_matrix:",cm)
print("Classification_report:",cr)
# Out:
# Accuracy:0.57
# Confusion_matrix: [[ 2  0  1  3  0]
#  [ 0  2  0  1  0]
#  [ 1  0  1  3  0]
#  [ 1  2  5  3  0]
#  [ 0  0  0  0 15]]
# Classification_report:               precision    recall  f1-score   support
#
#        drugA       0.50      0.33      0.40         6
#        drugB       0.50      0.67      0.57         3
#        drugC       0.14      0.20      0.17         5
#        drugX       0.30      0.27      0.29        11
#        drugY       1.00      1.00      1.00        15
#
#     accuracy                           0.57        40
#    macro avg       0.49      0.49      0.48        40
# weighted avg       0.59      0.57      0.58        40

# %%
plt.figure(figsize=(15,10))
plot_tree(clf,filled=True,feature_names=list(x),class_names=list(y))
plt.show()
