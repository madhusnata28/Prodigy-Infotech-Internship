# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/MADHUSNATA KAR/Documents/Prodigy_Infotech/Task5_sheet.csv")
data
# Out:
#          Unnamed: 0  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0                 0               525680.0                  178240  -0.191170
# 1                 1               524170.0                  181650  -0.211708
# 2                 2               524520.0                  182240  -0.206458
# 3                 3               526900.0                  177530  -0.173862
# 4                 4               528060.0                  179040  -0.156618
# ...             ...                    ...                     ...        ...
# 1048570        9117               530140.0                  170990  -0.129632
# 1048571        9118               529820.0                  170510  -0.134408
# 1048572        9119               530650.0                  176730  -0.120183
# 1048573        9120               532220.0                  172500  -0.099170
# 1048574        9121               531180.0                  177000  -0.112456
#
# ...

# %%
print(data.isnull().sum())
# Out:
# Unnamed: 0                      0
# Location_Easting_OSGR         101
# Location_Northing_OSGR          0
# Longitude                     101
# Latitude                        0
# Accident_Severity               0
# Number_of_Vehicles              0
# Number_of_Casualties            0
# Day_of_Week                     0
# Time                          104
# Junction_Control           426362
# Light_Conditions                0
# Weather_Conditions              0
# Road_Surface_Conditions         0
# Year                            0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info
# Out:
# <bound method DataFrame.info of          Unnamed: 0  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 1                 1               524170.0                  181650  -0.211708
# 6                 6               524220.0                  180830  -0.211277
# 8                 8               527350.0                  177650  -0.167342
# 9                 9               524550.0                  180810  -0.206531
# 10               10               526240.0                  178900  -0.182872
# ...             ...                    ...                     ...        ...
# 1048570        9117               530140.0                  170990  -0.129632
# 1048571        9118               529820.0                  170510  -0.134408
# 1048572        9119               530650.0                  176730  -0.120183
# 1048573        9120               532220.0                  172500  -0.099170
# 1048574        9121               531180.0                  177000  -0.112456
#
# ...

# %%
data.describe()
# Out:
#           Unnamed: 0  Location_Easting_OSGR  Location_Northing_OSGR  \
# count  622124.000000          622124.000000            6.221240e+05
# mean   253650.861132          443585.735850            2.955779e+05
# std    155482.181848           91760.643391            1.533887e+05
# min         0.000000           65860.000000            1.052000e+04
# 25%    118359.000000          383410.000000            1.789200e+05
# 50%    249533.500000          442700.000000            2.674700e+05
# 75%    383678.250000          525320.000000            3.956400e+05
# max    570010.000000          655370.000000            1.198000e+06
#
#            Longitude       Latitude  Accident_Severity  Number_of_Vehicles  \
# count  622124.000000  622124.000000      622124.000000       622124.000000
# mean       -1.377701      52.548534           2.867141            1.880394
# std         1.346324       1.381738           0.362595            0.606003
# ...

# %%
sns.countplot(x='Day_of_Week',data=data)
plt.title('Frequency of accidents with respect to each day')
plt.show()

#Here 1 represents Sunday, 2 for Monday, 3 for Tuesday, 4 for Wednesday, 5 for Thursday, 6 for Friday, 7 for Saturday

# %%
sns.barplot(x='Number_of_Casualties', y='Accident_Severity',data=data)
plt.title('No. of casualties with respect to accident severity')
plt.show()

# %%
sns.countplot(x='Road_Surface_Conditions',data=data)
plt.title('Frequency of accidents with respect to road condition')
plt.xticks(rotation=90)
plt.show()

# %%
avg_sev=data.groupby('Road_Surface_Conditions')['Accident_Severity'].value_counts()
print("Average severity of accidents by road conditions:")
print(avg_sev)
# Out:
# Average severity of accidents by road conditions:
# Road_Surface_Conditions    Accident_Severity
# Dry                        3                    387917
#                            2                     53372
#                            1                      3691
# Flood (Over 3cm of water)  3                       227
#                            2                        40
#                            1                         1
# Frost/Ice                  3                      7932
#                            2                       825
#                            1                        46
# Normal                     3                       689
#                            2                        57
#                            1                         4
# Snow                       3                      2998
#                            2                       240
#                            1                        18
# ...

# %%
sns.countplot(x='Light_Conditions',data=data)
plt.title('Frequency of accidents with respect to light condition')
plt.xticks(rotation=90)
plt.show()

# %%
avg_sev=data.groupby('Light_Conditions')['Accident_Severity'].value_counts()
print("Average severity of accidents by light conditions:")
print(avg_sev)
# Out:
# Average severity of accidents by light conditions:
# Light_Conditions                           Accident_Severity
# Darkeness: No street lighting              3                     10137
#                                            2                      2305
#                                            1                       413
# Darkness: Street lighting unknown          3                      4491
#                                            2                       521
#                                            1                        32
# Darkness: Street lights present and lit    3                    118349
#                                            2                     18541
#                                            1                      1387
# Darkness: Street lights present but unlit  3                      2218
#                                            2                       326
#                                            1                        27
# ...

# %%
sns.countplot(x='Weather_Conditions',data=data)
plt.title('Frequency of accidents with respect to weather condition')
plt.xticks(rotation=90)
plt.show()

# %%
avg_sev=data.groupby('Weather_Conditions')['Accident_Severity'].value_counts()
print("Average severity of accidents by weather conditions:")
print(avg_sev)
# Out:
# Average severity of accidents by weather conditions:
# Weather_Conditions          Accident_Severity
# Fine with high winds        3                      6127
#                             2                       905
#                             1                        88
# Fine without high winds     3                    439161
#                             2                     60860
#                             1                      4334
# Fog or mist                 3                      2392
#                             2                       326
#                             1                        36
# Other                       3                     12536
#                             2                      1212
#                             1                        56
# Raining with high winds     3                      6174
#                             2                       822
#                             1                        68
# ...

# %%
sns.countplot(x='Year',data=data)
plt.title('Frequency of accidents with respect to year')
plt.xticks(rotation=90)
plt.show()

# %%
avg_sev=data.groupby('Year')['Accident_Severity'].value_counts()
print("Average severity of accidents by year:")
print(avg_sev)
# Out:
# Average severity of accidents by year:
# Year  Accident_Severity
# 2005  3                    102645
#       2                     12695
#       1                      1035
# 2006  3                     96829
#       2                     12790
#       1                      1028
# 2007  3                     92322
#       2                     12654
#       1                      1001
# 2009  3                     84705
#       2                     11603
#       1                       744
# 2010  3                     80869
#       2                     10843
#       1                       597
# 2011  3                     80639
#       2                     11487
#       1                       653
# 2012  3                      6520
#       2                       463
#       1                         2
# Name: count, dtype: int64
